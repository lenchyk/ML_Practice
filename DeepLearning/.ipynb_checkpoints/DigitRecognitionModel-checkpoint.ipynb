# %%
#input data
mnist = input_data.read_data_sets("datasets/MNIST_data/", one_hot="True")

#create a model
x = tf.placeholder(tf.float32, [None, 784])
W = tf.Variable(tf.zeros([784, 10]))
b = tf.Variable(tf.zeros([10]))
y = tf.matmul(x, W) + b   # y = W*x + b  --- matrix form

#define loss and optimizer
y_ = tf.placeholder(tf.float32, [None, 10]) # labels for digits 0-9 - flat vector
# Hy′(y)=−∑y′ilog(yi)
#cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y))
py = tf.nn.softmax(y)
cross_entropy = tf.reduce_mean(-tf.reduce_sum(y_ * tf.log(py), reduction_indices=[1]))
train_step = tf.train.GradientDescentOptimizer(0.5).minimize(cross_entropy)

#create session and initializing all variables
sess = tf.Session()
sess.run(tf.global_variables_initializer())

#training a model
for _ in trange(1000):
    batch_xs, batch_ys = mnist.train.next_batch(100)
    sess.run(train_step, feed_dict={x: batch_xs, y_: batch_ys})

#test trained model
correct_prediction = tf.equal(tf.argmax(py, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
print('Test accuracy - {0}'.format(sess.run(accuracy, feed_dict={x: mnist.test.images, y_: mnist.test.labels})))

# Get weights
weights = sess.run(W)

fig, ax = plt.subplots(1, 10, figsize=(20, 2))

for digit in range(10):
    ax[digit].imshow(weights[:,digit].reshape(28,28), cmap='gray')

# Close session to finish
sess.close()
# Out:
# Extracting datasets/MNIST_data/train-images-idx3-ubyte.gz
# Extracting datasets/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting datasets/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting datasets/MNIST_data/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 1000/1000 [00:01<00:00, 611.26it/s]
# Test accuracy - 0.9178000092506409

# %%
import tensorflow as tf
from tqdm import trange  # for progress bar
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5faa65234dfb> in <module>
#       1 import tensorflow as tf
#       2 from tqdm import trange
# ----> 3 from tensorflow.examples.tutorials.mnist import input_data
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# ~/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/examples/tutorials/mnist/__init__.py in <module>
#      19 from __future__ import print_function
#      20
# ---> 21 from tensorflow.examples.tutorials.mnist import input_data
#      22 from tensorflow.examples.tutorials.mnist import mnist
#
# ~/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/examples/tutorials/mnist/input_data.py in <module>
#      28 from six.moves import xrange  # pylint: disable=redefined-builtin
#      29 import tensorflow as tf
# ---> 30 from tensorflow.contrib.learn.python.learn.datasets.mnist import read_data_sets
#      31 # pylint: enable=unused-import
#
# ModuleNotFoundError: No module named 'tensorflow.contrib'
